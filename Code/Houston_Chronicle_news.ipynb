# %%
import pandas as pd
from bs4 import BeautifulSoup
import urllib.request as urllib2

# Opens the required website

Title = []
Date = []
Author = []
Content = []

for i in range(1,50):
    url = "https://www.chron.com/search/?action=search&searchindex=solr&query=HIV&page=i"
    html_page = urllib2.urlopen(url)
    soup = BeautifulSoup(html_page)

# Extract the title of the article
    items_has_photo = soup.find_all("div", attrs={"class": "gsa-item gsa-item-regular has-photo"})
    

    for item in items_has_photo:
        Tit = item.find("h2", attrs={"class": "headline"})
        Dat = item.find('span',attrs={"class": "timestamp"})
        Aut = item.find("span", attrs={"class": "byline"})
        Con = item.find("p", attrs={"class": "blurb"})
        Title.append(Tit.text)
        if Dat != None:
            Date.append(Dat.text)
        else:
            Date.append("None")
        if Aut != None:
            Author.append(Aut.text)
        else:
            Author.append("None")
        if Con != None:
             Content.append(Con.text)
        else:
            Content.append("None")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\ProgramData\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
d = {'Title': Title, 'Date': Date, 'Author': Author, 'Content': Content}
df = pd.DataFrame(data=d)

# %%
df.to_csv('Houston_Chronicle.csv',index = False)

# %%
df
# Out:
#                                                  Title               Date  \
# 0    \n\n                        Thomas Street Heal...  December 11, 2018
# 1    \n\n                        Record-breaking "H...      July 16, 2018
# 2    \n\n                        Houston man who in...      June 21, 2018
# 3    \n\n                        Galveston County c...     March 27, 2018
# 4    \n\n                        Patients at 2 Galv...     March 23, 2018
# 5    \n\n                        Girl's HIV infecti...      July 24, 2017
# 6    \n\n                        Maxwell: Meth and ...     August 3, 2016
# 7    \n\nHIV Prevention Summit aims to help reduce ...   January 30, 2016
# 8    \n\nHIV Prevention Summit aims to help reduce ...   January 30, 2016
# 9    \n\nHIV Prevention Summit aims to help reduce ...   January 30, 2016
# 10   \n\n                        Charlie Sheen pred...    January 7, 2016
# 11   \n\n                        Sex offender who g...     March 17, 2016
# 12   \n\n                        Celebs react to Ch...  November 18, 2015
# 13   \n\n                        Charlie Sheen: 'I ...  November 17, 2015
# 14   \n\n                        Thomas Street Heal...  December 11, 2018
# 15   \n\n                        Record-breaking "H...      July 16, 2018
# 16   \n\n                        Houston man who in...      June 21, 2018
# 17   \n\n                        Galveston County c...     March 27, 2018
# 18   \n\n                        Patients at 2 Galv...     March 23, 2018
# 19   \n\n                        Girl's HIV infecti...      July 24, 2017
# 20   \n\n                        Maxwell: Meth and ...     August 3, 2016
# 21   \n\nHIV Prevention Summit aims to help reduce ...   January 30, 2016
# 22   \n\nHIV Prevention Summit aims to help reduce ...   January 30, 2016
# 23   \n\nHIV Prevention Summit aims to help reduce ...   January 30, 2016
# 24   \n\n                        Charlie Sheen pred...    January 7, 2016
# 25   \n\n                        Sex offender who g...     March 17, 2016
# 26   \n\n                        Celebs react to Ch...  November 18, 2015
# 27   \n\n                        Charlie Sheen: 'I ...  November 17, 2015
# 28   \n\n                        Thomas Street Heal...  December 11, 2018
# 29   \n\n                        Record-breaking "H...      July 16, 2018
# 16           Dana Burke  \n        In April 2014, the woman began to ex...
# 17          Nick Powell  \n        "Let me just say this, we see all pa...
# 18          Nick Powell  \n        No infections found, but county has ...
# 19   MARILYNN MARCHIONE  \n        Current treatments keep HIV under co...
# 20         Jane Maxwell  \n        Specifically in Texas, this new meth...
# 21     Community report  \n        Community report In conjunction with...
# 22     Community report  \n        Community report In conjunction with...
# 23     Community report  \n        Community report In conjunction with...
# 24           Daily Dish  \n        Celebrity Buzz Daily Dish TODAY - Pi...
# 25                 None  \n        A repeat sex offender who infected a...
# 26         Nick Paschal  \n        Tubular Nick Paschal "What Just Happ...
# 27           Daily Dish  \n        Celebrity Buzz Daily Dish Actor Char...
# 28          StoryStudio  \n        It was the first freestanding HIV/AI...
# 29        Amber Elliott  \n        Cormier and fellow co-chairs Tony Br...
# ..                  ...                                                ...
# 656        Nick Paschal  \n        Tubular Nick Paschal "What Just Happ...
# 657          Daily Dish  \n        Celebrity Buzz Daily Dish Actor Char...
# 658         StoryStudio  \n        It was the first freestanding HIV/AI...
# 659       Amber Elliott  \n        Cormier and fellow co-chairs Tony Br...
# 660          Dana Burke  \n        In April 2014, the woman began to ex...
# 661         Nick Powell  \n        "Let me just say this, we see all pa...
# 662         Nick Powell  \n        No infections found, but county has ...
# 663  MARILYNN MARCHIONE  \n        Current treatments keep HIV under co...
# 664        Jane Maxwell  \n        Specifically in Texas, this new meth...
# 665    Community report  \n        Community report In conjunction with...
# 666    Community report  \n        Community report In conjunction with...
# 667    Community report  \n        Community report In conjunction with...
# 668          Daily Dish  \n        Celebrity Buzz Daily Dish TODAY - Pi...
# 669                None  \n        A repeat sex offender who infected a...
# 670        Nick Paschal  \n        Tubular Nick Paschal "What Just Happ...
# 671          Daily Dish  \n        Celebrity Buzz Daily Dish Actor Char...
# 672         StoryStudio  \n        It was the first freestanding HIV/AI...
# 673       Amber Elliott  \n        Cormier and fellow co-chairs Tony Br...
# 674          Dana Burke  \n        In April 2014, the woman began to ex...
# 675         Nick Powell  \n        "Let me just say this, we see all pa...
# 676         Nick Powell  \n        No infections found, but county has ...
# 677  MARILYNN MARCHIONE  \n        Current treatments keep HIV under co...
# 678        Jane Maxwell  \n        Specifically in Texas, this new meth...
# 679    Community report  \n        Community report In conjunction with...
# 680    Community report  \n        Community report In conjunction with...
# 681    Community report  \n        Community report In conjunction with...
# 682          Daily Dish  \n        Celebrity Buzz Daily Dish TODAY - Pi...
# 683                None  \n        A repeat sex offender who infected a...
# 684        Nick Paschal  \n        Tubular Nick Paschal "What Just Happ...
# 685          Daily Dish  \n        Celebrity Buzz Daily Dish Actor Char...
#
# [686 rows x 4 columns]

# %%
df1 = df

# %%
i = 7
while i<686:
    df1.drop([i,i+1])
    i = i + 14

# %%
df1.drop?
