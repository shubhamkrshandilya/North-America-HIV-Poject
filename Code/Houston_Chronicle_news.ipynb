# %%
import pandas as pd
from bs4 import BeautifulSoup
import urllib.request as urllib2

# Opens the required website

Title = []
Date = []
Author = []
Content = []

for i in range(1,50):
    url = "https://www.chron.com/search/?action=search&searchindex=solr&query=HIV&page=i"
    html_page = urllib2.urlopen(url)
    soup = BeautifulSoup(html_page)

# Extract the title of the article
    items_has_photo = soup.find_all("div", attrs={"class": "gsa-item gsa-item-regular has-photo"})
    items_no_photo = soup.find_all("div", attrs={"class": "gsa-item gsa-item-regular no-photo"})
    

    for item in items_has_photo:
        Tit = item.find("h2", attrs={"class": "headline"})
        Dat = item.find('span',attrs={"class": "timestamp"})
        Aut = item.find("span", attrs={"class": "byline"})
        Con = item.find("p", attrs={"class": "blurb"})
        Title.append(Tit.text)
        if Dat != None:
            Date.append(Dat.text)
        else:
            Date.append("None")
        if Aut != None:
            Author.append(Aut.text)
        else:
            Author.append("None")
        if Con != None:
             Content.append(Con.text)
        else:
            Content.append("None")
    
        for item in items_no_photo:
            Tit = item.find("h2", attrs={"class": "headline"})
            Dat = item.find('span',attrs={"class": "timestamp"})
            Aut = item.find("span", attrs={"class": "byline"})
            Con = item.find("p", attrs={"class": "blurb"})
            Title.append(Tit.text)
            if Dat != None:
                Date.append(Dat.text)
            else:
                Date.append("None")
            if Aut != None:
                Author.append(Aut.text)
            else:
                Author.append("None")
            if Con != None:
                Content.append(Con.text)
            else:
                Content.append("None")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\ProgramData\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
d = {'Title': Title, 'Date': Date, 'Author': Author, 'Content': Content}
df = pd.DataFrame(data=d)

# %%
df.to_csv('Houston_Chronicle.csv',index = False)

# %%
df
# Out:
#                                                   Title                Date  \
# 0     \n\n                        Thomas Street Heal...   December 11, 2018
# 1     \n\n                        Fake doctor in Ind...    February 6, 2018
# 2     \n\n                        Trump ends terms o...   December 30, 2017
# 3     \n\n                        Woman learns she h...      August 5, 2016
# 4     \n\n                        Study finds HIV-po...        May 10, 2016
# 5     \n\n                        WHO pushes for mil...  September 30, 2015
# 6     \n\nHIV-positive woman hiding status from men ...        July 6, 2015
# 7     \n\n                        Record-breaking "H...       July 16, 2018
# 8     \n\n                        Fake doctor in Ind...    February 6, 2018
# 9     \n\n                        Trump ends terms o...   December 30, 2017
# 10    \n\n                        Woman learns she h...      August 5, 2016
# 11    \n\n                        Study finds HIV-po...        May 10, 2016
# 12    \n\n                        WHO pushes for mil...  September 30, 2015
# 13    \n\nHIV-positive woman hiding status from men ...        July 6, 2015
# 14    \n\n                        Houston man who in...       June 21, 2018
# 15    \n\n                        Fake doctor in Ind...    February 6, 2018
# 16    \n\n                        Trump ends terms o...   December 30, 2017
# 17    \n\n                        Woman learns she h...      August 5, 2016
# 18    \n\n                        Study finds HIV-po...        May 10, 2016
# 19    \n\n                        WHO pushes for mil...  September 30, 2015
# 20    \n\nHIV-positive woman hiding status from men ...        July 6, 2015
# 21    \n\n                        Galveston County c...      March 27, 2018
# 22    \n\n                        Fake doctor in Ind...    February 6, 2018
# 23    \n\n                        Trump ends terms o...   December 30, 2017
# 24    \n\n                        Woman learns she h...      August 5, 2016
# 25    \n\n                        Study finds HIV-po...        May 10, 2016
# 26    \n\n                        WHO pushes for mil...  September 30, 2015
