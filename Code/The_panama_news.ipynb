# %%
import pandas as pd
from bs4 import BeautifulSoup
import urllib.request as urllib2

# %%
#Region = []
Title = []
Date = []
Author = []
Content = []

for i in range(0,11):
    url = "http://www.thepanamanews.com/page/"+str(i)+"/?s=hiv"
    html_page = urllib2.urlopen(url)
    #html_page = urllib2.urlopen(url)
    soup = BeautifulSoup(html_page)

# Extract the title of the article
    items = soup.find_all("div", attrs={"class": "td_module_16"})
    #print(items)
    

    for item in items:
        #Reg = item.find("a", attrs={"class": "trb_search_result_section"})
        Tit = item.find("h3", attrs={"class": "entry-title"})
        #print(Tit)
        Dat = item.find("span", attrs={"class": "td-post-date"})
        Aut = item.find("span", attrs={"class": "td-post-author-name"})
        Con = item.find("div", attrs={"class": "td-excerpt"})
        Date.append(Dat.text)
        #print(Dat)
        
        Title.append(Tit.text)
        #print(Tit.text)
        #if Dat.has_attr('datetime'):
            #Date.append(Dat['datetime'])

        if Aut != None:
            Author.append(Aut.text)
        else:
            Author.append("None")
        if Con != None:
             Content.append(Con.text)
        else:
            Content.append("None")
    #print(len(Title))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\ProgramData\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
d = {'Title': Title, 'Date': Date,'Author': Author, 'Content': Content}
df = pd.DataFrame(data=d)

# %%
df
# Out:
#                                                  Title                Date  \
# 0    World Health Organization encourages HIV self-...   November 29, 2016
# 1         Retrieved archives from an infamous campaign   November 16, 2015
# 2    Archives: An unauthorized look at US military ...   December 25, 2010
# 3             La huella regional del Dr. Richard Cooke        June 5, 2019
# 4           ¿Wappin? Music for a rainy last day of May        May 31, 2019
# 5                     STRI, Los justicieros del bosque        May 28, 2019
# 6        Larvas misteriosas en ambos océanos de Panamá        May 15, 2019
# 7        Gandásegui, No prospects for change in Panama         May 2, 2019
# 8                       Campaigns approach their ends…      April 30, 2019
# 9                  Los debates presidenciales formales      April 11, 2019
# 10   World Health Organization encourages HIV self-...   November 29, 2016
# ...

# %%
newContent = []

# %%
for i in df['Content']:
    i = i.replace('\n', '')
    i = i.replace('\t', '')
    i = i.replace('\r', '')
    newContent.append(i)

# %%
d = {'Title': Title, 'Date': Date,'Author': Author, 'Content': newContent}
df = pd.DataFrame(data=d)

# %%
df = df.drop_duplicates(subset=None, keep='first', inplace=False)

# %%
df
# Out:
#                                                  Title                Date  \
# 0    World Health Organization encourages HIV self-...   November 29, 2016
# 1         Retrieved archives from an infamous campaign   November 16, 2015
# 2    Archives: An unauthorized look at US military ...   December 25, 2010
# 3             La huella regional del Dr. Richard Cooke        June 5, 2019
# 4           ¿Wappin? Music for a rainy last day of May        May 31, 2019
# 5                     STRI, Los justicieros del bosque        May 28, 2019
# 6        Larvas misteriosas en ambos océanos de Panamá        May 15, 2019
# 7        Gandásegui, No prospects for change in Panama         May 2, 2019
# 8                       Campaigns approach their ends…      April 30, 2019
# 9                  Los debates presidenciales formales      April 11, 2019
# 20                 World Health Statistics Report 2019       April 6, 2019
# ...

# %%
df.to_csv('The_panama_news.csv',index=False)

# %%
df
# Out:
#                                                  Title                Date  \
# 0    World Health Organization encourages HIV self-...   November 29, 2016
# 1         Retrieved archives from an infamous campaign   November 16, 2015
# 2    Archives: An unauthorized look at US military ...   December 25, 2010
# 3             La huella regional del Dr. Richard Cooke        June 5, 2019
# 4           ¿Wappin? Music for a rainy last day of May        May 31, 2019
# 5                     STRI, Los justicieros del bosque        May 28, 2019
# 6        Larvas misteriosas en ambos océanos de Panamá        May 15, 2019
# 7        Gandásegui, No prospects for change in Panama         May 2, 2019
# 8                       Campaigns approach their ends…      April 30, 2019
# 9                  Los debates presidenciales formales      April 11, 2019
# 10   World Health Organization encourages HIV self-...   November 29, 2016
# ...
